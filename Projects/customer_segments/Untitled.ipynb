# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
blobs = make_blobs(n_samples=100, n_features=2)[0]

# %%
plt.scatter(blobs[:,0],blobs[:,1]);
verbose = True

k_max = 7
data = blobs
avg_diff = np.zeros(k_max)

for k in range(1, k_max+1):
    if verbose: print("k = "+ str(k))
    
    kmeans_ = KMeans(n_clusters = k)
    model_  = kmeans_.fit(data)
    labels_ = model_.predict(data)
    
    center_array_ = [list(model_.cluster_centers_[labels_[j]]) for j in range(0,len(labels_))] 
    
#     X = data[labels_ == j] - np.array(center_array_)[labels_ == j]
#     np.mean(np.sqrt(X[:,0]**2 + X[:,1]**2))
    
#     distances_ = [np.sqrt(X[:,0]**2 + X[:,1]**2) for j in range(0,max(labels_)+1)]
    
    distances_ = [np.linalg.norm(data[labels_ == j] - np.array(center_array_)[labels_ == j]) for j in range(0,max(labels_)+1)]
    
    
    avg_diff[k-1] = np.mean(distances_)
    
fig = plt.figure()
plt.plot(np.array(range(1,k_max+1)), avg_diff, marker = 'x', color = 'r')
plt.xlabel('Number of clusters')
plt.ylabel('Avg. distance to nearest cluster centre')
plt.title('Finding K: Kmeans Elbow Method');
# Out:
# k = 1
# k = 2
# k = 3
# k = 4
# k = 5
# k = 6
# k = 7

# %%
test=[i for i in range(1,k_max+1)]

# %%
test
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
fig = plt.figure()
plt.plot(np.array(range(1,k_max+1)), avg_diff, marker = 'x', color = 'r')
plt.xlabel('Number of clusters')
plt.ylabel('Avg. distance to nearest cluster centre')
plt.title('Finding K: Kmeans Elbow Method');
plt.xticks(ticks=test);

# %%
womenMeans = (25, 32, 34, 20, 25)
womenStd =   (3, 5, 2, 3, 3)
menMeans = (20, 35, 30, 35, 27)
menStd =   (2, 3, 4, 1, 2)

N = 5

# %%
import numpy as np
import matplotlib.pyplot as plt

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

rects1 = ax.bar(ind, menMeans, width =0.35, color='royalblue')
rects2 = ax.bar(ind+width, womenMeans, width =0.35, color='seagreen')

ax.set_xticks(ind + width / 2)
ax.set_xticklabels( ('G1', 'G2', 'G3', 'G4', 'G5') )

plt.show()

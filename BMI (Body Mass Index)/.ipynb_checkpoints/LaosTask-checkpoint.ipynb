# %%
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
# help(pd)

# %%
bmi_life_data = pd.read_csv('/Users/Administrator/Documents/Work/pylearn/BMI (Body Mass Index)/data.csv')

# %%
bmi_life_data
# Out:
#                 Country  Life expectancy       BMI
# 0           Afghanistan             52.8  20.62058
# 1               Albania             76.8  26.44657
# 2               Algeria             75.5  24.59620
# 3               Andorra             84.6  27.63048
# 4                Angola             56.7  22.25083
# ..                  ...              ...       ...
# 158             Vanuatu             63.4  26.78926
# 159  West Bank and Gaza             74.1  26.57750
# 160             Vietnam             74.1  20.91630
# 161              Zambia             51.1  20.68321
# 162            Zimbabwe             47.3  22.02660
#
# [163 rows x 3 columns]

# %%
x_bm = np.array(bmi_life_data['BMI']).reshape(-1,1)
y_le = np.array(bmi_life_data['Life expectancy']).reshape(-1,1)
print('BMI = \n',x_bm)
print('Life Expectancy = \n',y_le)
# Out:
# BMI =
#  [[20.62058]
#  [26.44657]
#  [24.5962 ]
#  [27.63048]
#  [22.25083]
#  [25.35542]
#  [27.56373]
#  [26.46741]
#  [25.65117]
#  [27.24594]
#  [20.39742]
#  [26.38439]
#  [26.16443]
#  [26.75915]
#  [27.02255]
#  [22.41835]
#  [22.8218 ]
#  [24.43335]
#  [26.61163]
#  [22.12984]
#  [25.78623]
#  [26.54286]
#  [21.27157]
#  [21.50291]
#  [20.80496]
#  [23.68173]
#  [27.4521 ]
#  [23.51522]
#  [21.48569]
#  [27.01542]
#  [22.92176]
#  [24.94041]
#  [22.06131]
#  [19.86692]
#  [21.87134]
#  [26.47897]
#  [22.56469]
#  [26.59629]
#  [25.06867]
#  [27.41899]
#  [26.13287]
#  [23.38403]
#  [25.58841]
#  [26.73243]
#  [26.36751]
#  [20.88509]
#  [26.26446]
#  [20.247  ]
#  [26.53078]
#  [26.73339]
#  [25.85329]
#  [30.86752]
#  [24.0762 ]
#  [21.65029]
#  [25.54942]
#  [27.16509]
#  [22.84247]
#  [26.33786]
#  [26.01359]
#  [25.17988]
#  [25.29947]
#  [22.52449]
#  [21.64338]
#  [23.68465]
#  [23.66302]
#  [25.10872]
#  [27.11568]
#  [27.20687]
#  [20.95956]
#  [21.85576]
# ...

# %%
bmi_life_model = linear_model.LinearRegression()
bmi_life_model.fit(x_bm,y_le)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
bmi_life_model.coef_
# Out:
# array([[2.51847944]])

# %%
bmi_life_model.intercept_
# Out:
# array([7.22783834])

# %%
laos_bmi = np.array([21.07931]).reshape(-1,1)
laos_life_exp = bmi_life_model.predict(laos_bmi)
print('Expected L.E. = ',laos_life_exp)
print('Neighbour Myanmar our L.E. = ',bmi_life_data[bmi_life_data['Country'] == "Myanmar"])
# Out:
# Expected L.E. =  [[60.31564716]]
# Neighbour Myanmar our L.E. =       Country  Life expectancy       BMI
# 102  Myanmar             59.4  21.44932

# %%
bmi_life_data[bmi_life_data['Country'] == "Brazil"]
bmi_life_data[bmi_life_data['Country'] == "Myanmar"]
# Out:
#      Country  Life expectancy       BMI
# 102  Myanmar             59.4  21.44932

# %%
### MY SUBMISSION (REFORMATTED)

# TODO: Add import statements
import numpy as np
import pandas as pd
from sklearn import linear_model

# Assign the dataframe to this variable.
# TODO: Load the data
# bmi_life_data = pd.read_csv('/Users/Administrator/Documents/Work/pylearn/BMI (Body Mass Index)/data.csv')
bmi_life_data = pd.read_csv("bmi_and_life_expectancy.csv")

# Make and fit the linear regression model
#TODO: Fit the model and Assign it to bmi_life_model
x_bm = np.array(bmi_life_data['BMI']).reshape(-1,1)
y_le = np.array(bmi_life_data['Life expectancy']).reshape(-1,1)
bmi_life_model = linear_model.LinearRegression()
bmi_life_model.fit(x_bm,y_le)

# Make a prediction using the model
# TODO: Predict life expectancy for a BMI value of 21.07931
laos_bmi = np.array([21.07931]).reshape(-1,1)
laos_life_exp = bmi_life_model.predict(laos_bmi)
